# %% [markdown]
# ## 7.1 Negentropy is scale-invariant

# %% [markdown]
# The covariance matrix of $x$: $\Sigma = E[(x-E[x])(x-E[x])^{T}]$
#
# The covariance matrix of $y$: $\Sigma_y = E[(Ax-E[Ax])(Ax-E[Ax])^{T}]$ where $y = Ax$
#
# A is invariant for $E[]$ Therefore
#
# \begin{eqnarray}
# \Sigma_y &=& E[(Ax-AE[x])(Ax-AE[x])^{T}] \\
#  &=& E[A(x-E[x])(A(x-E[x]))^{T}] \\
#  &=& A \:E[(x-E[x])((x-E[x]))^{T}A^T] \\
# \Sigma_y  &=& A \Sigma A^T
# \end{eqnarray}
#
# Then $H(y_{Gauss})=\frac{1}{2} \log{|\det{\Sigma_y}|}+ \frac{1}{2}(1+\log{2\pi})$
#
# \begin{eqnarray}
# H(y_{Gauss})&=&\frac{1}{2} \log{|\det(\Sigma_y)|}+ \frac{1}{2}(1+\log{2\pi}) \\
# &=&\frac{1}{2} \log{|\det( A \Sigma A^T)|}+ \frac{1}{2}(1+\log{2\pi})
# \end{eqnarray}
#
# $|\det( A \Sigma A^T)|=|\det( A) \det( \Sigma ) \det(A^T)| $
#
# $=|\det( A) \det( \Sigma ) \det(A)| $
#
# $=\det( A)^2 |\det( \Sigma )| $
#
# Therefore
#
# \begin{eqnarray}
# & &\frac{1}{2} \log{|\det( A \Sigma A^T)|}+ \frac{1}{2}(1+\log{2\pi}) \\
# &=& \frac{1}{2} \log{\det( A)^2 |\det( \Sigma )|}+ \frac{1}{2}(1+\log{2\pi}) \\
# &=& \log{\det( A)}+ \frac{1}{2} \log{|\det( \Sigma )|}+ \frac{1}{2}(1+\log{2\pi}) \\
# H(y_{Gauss})&=& \log{\det( A)}+ H(x_{Gauss}))
# \end{eqnarray}
#
# If we estimate a probability density is maltivariate gaussian
#
# \begin{eqnarray}
# p(x) = \frac{1}{(\sqrt{2\pi})^m \sqrt{|\det(\Sigma)|}} \exp(-\frac{1}{2} (x-E[x])^T \Sigma^{-1}(x-E[x]))
# \end{eqnarray}
#
# Then
#
# \begin{eqnarray}
# p(Ax) &=& \frac{1}{(\sqrt{2\pi})^m \sqrt{\det( A)^2 |\det( \Sigma )|}} \exp(-\frac{1}{2} (Ax-E[Ax])^T (A \Sigma A^T)^{-1}(Ax-E[Ax])) \\
# &=& \frac{1}{\det( A)} \frac{1}{(\sqrt{2\pi})^m \sqrt{|\det( \Sigma )|}} \exp(-\frac{1}{2} (Ax-E[Ax])^T (A \Sigma A^T)^{-1}(Ax-E[Ax])) \\
# &=& \frac{1}{\det( A)} \frac{1}{(\sqrt{2\pi})^m \sqrt{|\det( \Sigma )|}} \exp(-\frac{1}{2} (x-E[x])^TA^T (A \Sigma A^T)^{-1}A(x-E[x])) \\
# &=& \frac{1}{\det( A)} \frac{1}{(\sqrt{2\pi})^m \sqrt{|\det( \Sigma )|}} \exp(-\frac{1}{2} (x-E[x])^TA^T (A^{-T} \Sigma^{-1} A^{-1})A(x-E[x])) \\
# &=& \frac{1}{\det( A)} \frac{1}{(\sqrt{2\pi})^m \sqrt{|\det( \Sigma )|}} \exp(-\frac{1}{2} (x-E[x])^T \Sigma^{-1} (x-E[x])) \\
# p(Ax) &=& \frac{1}{\det( A)} p(x) \\
# \end{eqnarray}
#
# We have the differential entropy:
#
# \begin{eqnarray}
# H(x)= -\int p(x)\log{p(x)} dx \\
# \end{eqnarray}
#
# \begin{eqnarray}
# H(Ax)&=& -\int \frac{1}{\det( A)} p(x) \log{\frac{1}{\det( A)} p(x)} dx \\
# &=&  -\frac{1}{\det( A)} \int p(x) \log{\frac{1}{\det( A)} p(x)} dx \\
# &=&  -\frac{1}{\det( A)} \int p(x)( \log{p(x)}-\log{\det( A)}) dx \\
# &=&  -\frac{1}{\det( A)} \int p(x) \log{p(x)}- p(x)\log{\det( A)} dx \\
# &=&  -\frac{1}{\det( A)} \int p(x) \log{p(x)} dx+\frac{1}{\det( A)} \int p(x)\log{\det( A)} dx \\
# &=&  - \int p(x) \log{p(x)} dx+\log{\det( A)} \int p(x) dx \\
# \end{eqnarray}
#
# $ \int p(x) dx = 1$ Therefore
#
# \begin{eqnarray}
# &=&  - \int p(x) \log{p(x)} dx+\log{\det( A)} \\
# H(Ax)&=& H(x) +\log{\det( A)}
# \end{eqnarray}
#
# The negentropy is defined as
#
# \begin{eqnarray}
# J(x) = H(x_{Gauss}) -H(x)
# \end{eqnarray}
#
# Then:
#
# \begin{eqnarray}
# J(Ax) &=& H(Ax_{Gauss}) -H(Ax) \\
# &=& \log{\det( A)}+ H(x_{Gauss}) - (H(x) +\log{\det( A)}) \\
# &=& H(x_{Gauss}) - H(x) = J(x)
# \end{eqnarray}

# %% [markdown]
# Therefore the negentropy is invariant w.r.t. invertible linear transformations.
#
# If $A=aI$ where $a \in \mathbb{R}$, $I$ is identical matrix $I \in \mathbb{R}^{n \times n} $ it is analog that the negentropy is scale invariant.

# %%
import numpy as np
import numpy.testing as npt
from scipy.linalg import expm
import matplotlib.pyplot as plt
import scipy.spatial, scipy.linalg
from scipy.spatial.distance import pdist
import scipy.sparse.linalg
from scipy.linalg import eigh
import zipfile,io
import pandas as pd
import zipfile
import re
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from sklearn.decomposition import FastICA, PCA
# %matplotlib inline

# %% [markdown]
# ## 7.2 fastICA vs. Infomax
#
# Apply fastICA to the two soundfiles data set (once again) of problem sheet 6 and compare runtime and robustness w.r.t. the mixing matrix A with the Infomax-based ICA-algorithm. Use the following setup for the latter algorithm: natural gradient, Bell-Sejnowski amplitude normalization, learning rate schedule "0 = 0:01, "t+1 = 0:9999"t.

# %%
unzip = zipfile.ZipFile("sounds.zip", 'r')          
fl = unzip.namelist()                     
s1 = unzip.open(fl[0])
s2 = unzip.open(fl[1])
dat1 = pd.read_table(s1,header=None,delim_whitespace=True)
dat2 = pd.read_table(s2,header=None,delim_whitespace=True)
sig1 = np.array(dat1)
sig2 = np.array(dat2)
S= np.append(sig1 ,sig2,1)
A =np.array( [[ 0.63610688,0.46237165], [ 0.95995455, 0.17711994]])
W = np.array([[ 0.58870338, 0.42567703],[ 0.66824231,0.62259454]])
X = np.dot(A,S.T)

# %%
def sigmoid(y):
    return 1/(1+np.exp(-y))

def natGrad(X, W, eps=0.01,l=0.9999):
    n = len(X)
    p=len(X[0])
    dw = np.array(W)
    ww = np.array(W)
    rmidx = np.random.choice(p,p,replace=False)
    XX=X[:,rmidx]
    # natural gradient  
    for i in range(p):
        y = np.dot(ww,XX[:,i].reshape(n,1))
        sig = 1 -2*sigmoid(y)
        dw= ww + np.dot(np.dot(sig,XX[:,i].reshape(1,n)),np.dot(ww.T,ww))
        ww=ww+eps*dw
        eps=eps*l
    return ww

def regGrad(XX, W, eps=0.01,l=0.9999):
    n = len(XX)
    p=len(XX[0])
    dw = np.array(W)
    ww = np.array(W)
    #“regular” gradient online
    for i in range(p):
        if(np.linalg.det(ww)==0.):
            ww = ww+np.eye(n)*0.0000000001
        invW= np.linalg.solve(ww,np.eye(n))
        y = np.dot(ww,XX[:,i].reshape(n,1))
        sig = 1 -2*sigmoid(y)
        dw =invW.T +np.dot(sig,XX[:,i].reshape(1,n))
        ww=ww+eps*dw
        eps=eps*l
    return ww

# %%
tm =time.time()
wr=regGrad(X, W, eps=0.01,l=0.9999)
sr = np.dot(wr,X)
print("Time of regulär gradient: ",time.time()-tm)
# Out:
# Time of regulär gradient:  7.321197986602783

# %%
tm =time.time()
wn=natGrad(X, W, eps=0.01,l=0.9999)
sn = np.dot(wn,X)
print("Time of  natural gradient: ",time.time()-tm)
# Out:
# Time of  natural gradient:  1.8259053230285645

# %%
tm =time.time()
ica = FastICA(n_components=2)
S_ = ica.fit_transform(X.T)  # Reconstruct signals
A_ = ica.mixing_  # Get estimated mixing matrix
print("Time of  fastICA: ",time.time()-tm)
# Out:
# Time of  fastICA:  0.6090538501739502

# %%
plt.figure(figsize=(12,12))
p = len(S)
lang = np.arange(p)

plt.subplot(5,2,1)
plt.plot(lang, S[:,0])
plt.title('Original signal 1' )
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,2)
plt.plot(lang, S[:,1])
plt.title('Original signal 2')
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,3)
plt.plot(lang, X.T[:,0])
plt.title('Mixed signal 1' )
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,4)
plt.plot(lang, X.T[:,1])
plt.title('Mixed signal 2')
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,5)
plt.plot(lang, sr.T[:,0])
plt.title('Demixed signal by reggrad 1' )
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,6)
plt.plot(lang, sr.T[:,1])
plt.title('Demixed signal by reggrad 2')
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,7)
plt.plot(lang, sn.T[:,0])
plt.title('Demixed signal by natgrad 1' )
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,8)
plt.plot(lang, sn.T[:,1])
plt.title('Demixed signal by reggrad 2' )
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,9)
plt.plot(lang, S_[:,0])
plt.title('Demixed signal by FastICA 1')
plt.xticks([])
plt.yticks([])

plt.subplot(5,2,10)
plt.plot(lang, S_[:,1])
plt.title('Demixed signal by FastICA 2' )
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# ## 7.3 ICA on Image Patches

# %% [markdown]
# The file imgpca.zip (used also in exercise sheet 2) contains three categories of images: nature, buildings, and text (prefixes n,b,t). For each category:

# %%
import matplotlib.cm as cm
from PIL import Image
import matplotlib.image as mpimg
import zipfile
import pylab
import io
zippath = 'imgpca.zip'
img = zipfile.ZipFile(zippath)

# %%
bilder_b = []
bilder_n = []
bilder_t = []

for i in range(10):    
    imgname = ('imgpca/b%i.jpg'%(i+1))
    bild_b = Image.open( io.BytesIO(img.read(imgname)) )
    bilder_b.append(bild_b)
    
for i in range(13):    
    imgname = ('imgpca/n%i.jpg'%(i+1))
    bild_n = Image.open( io.BytesIO(img.read(imgname)) )
    bilder_n.append(bild_n)
    

for i in range(14):    
    imgname = ('imgpca/t%i.jpg'%(i+1))
    bild_t = Image.open( io.BytesIO(img.read(imgname)) )
    bilder_t.append(bild_t)
    
bilder = [bilder_b,bilder_n,bilder_t]
mix = bilder_b+bilder_n+bilder_t

# %% [markdown]
# (a) Sample P patches of $\sqrt{N} \times \sqrt{N}$ pixels from all images of this category and rearrange each sample to a column vector. Choose number and size of the patches according to your computing resources. Recommended are P ≥ 20000 and N ≥ 144.

# %%
m = len(mix)
P = 20000
n =16

# %%
num=np.random.choice(m,P)
patches = np.empty((P,n,n))
pthcol = np.empty((P,n*n))
for i in range(P):
    tmp = np.array(mix[num[i]])
    shp = tmp.shape
    rs = np.random.choice(shp[0]-n,1)
    cs = np.random.choice(shp[1]-n,1)
    patches[i] = tmp[rs:rs+n,cs:cs+n]
    pthcol[i] = tmp[rs:rs+n,cs:cs+n].reshape(n*n)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:9: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:10: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future

# %%
plt.imshow(patches[1300],cmap=pylab.gray())

# %% [markdown]
# (b) Calculate the independent features of the image patches (these are the columns of mixing matrix A). Use a fastICA toolbox to compute this matrix:
#
# • Let fastica perform PCA and whitening of the data.
#
# • Use the contrast function G(^ s) = a 1 log cosh(as ^) with a = 1

# %%
def G(x,a=1):
    return np.log(np.cosh(a*x))/a,np.tanh(a*x)

# %%
G(10)
# Out:
# (9.3068528215012076, 0.99999999587769273)

# %%
pthcol.shape
# Out:
# (20000, 256)

# %%
imgica = FastICA(n_components=256,whiten=True)
S_img = imgica.fit_transform(pthcol)  # Reconstruct signals
A_img = imgica.mixing_  # Get estimated mixing matrix

# %%
A_img.shape
# Out:
# (256, 256)

# %% [markdown]
# (c) Show the first 20 independent features as (grayscale) image patches by rearranging the vectors into  $\sqrt{N} \times \sqrt{N}$  matrices and compare the results for the different categories. Order the independent features by decreasing negentropy, (such that the first feature has largest (approximated) negentropy etc).

# %%
plt.figure(figsize=(10,8))
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.title("%d th independent feature"%(i+1))
    plt.imshow(A_img[:,i].reshape(n,n),cmap=pylab.gray())

# %% [markdown]
# (d) Perform PCA on the same set of patches, plot the the principal components (ordered by decreasing eigenvalue) as in (c) and compare them with the independent features.

# %%
class myPCA():
    def __init__(self, X):
        # ...
        C = np.cov(X)
        D, U = np.linalg.eigh(C)
        idx = np.argsort(-D)
        self.U = U[:,idx]
        self.D = D[idx]
        
    def project(self, X, m):
        # ...
        U = self.U
        M = U[:,:m] 
        Z = np.dot(M.T,X)
        return Z
    
    def denoise(self, X, m):
        Z = self.project(X,m)
        U = self.U
        Y = np.dot(U[:,:m],Z)
        Y = Y + np.mean(X,axis=1).reshape(len(Y),1)
        return Y

# %%
imgpca= myPCA(pthcol.T)
U = imgpca.U

# %%
plt.figure(figsize=(10,8))
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.title("%d th independent feature by PCA"%(i+1))
    plt.imshow(U[:,i].reshape(n,n),cmap=pylab.gray())
